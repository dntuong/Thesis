# %% [markdown]
# # Data extractor

# %%
# rawnet3
import re

dataset = """
Epoch 1, TEER/TAcc 25.76, TLOSS 4.932107, LR 0.001000
Epoch 1, VEER 14.2500, MinDCF 0.69030
Epoch 2, TEER/TAcc 60.70, TLOSS 1.791377, LR 0.001000
Epoch 2, VEER 11.4000, MinDCF 0.57850
Epoch 3, TEER/TAcc 70.51, TLOSS 1.317087, LR 0.001000
Epoch 3, VEER 10.2200, MinDCF 0.56930
Epoch 4, TEER/TAcc 75.66, TLOSS 1.090966, LR 0.001000
Epoch 4, VEER 10.3000, MinDCF 0.53600
Epoch 5, TEER/TAcc 78.78, TLOSS 0.954119, LR 0.001000
Epoch 5, VEER 9.5200, MinDCF 0.49820
Epoch 6, TEER/TAcc 81.03, TLOSS 0.865763, LR 0.001000
Epoch 6, VEER 9.0100, MinDCF 0.46040
Epoch 7, TEER/TAcc 82.59, TLOSS 0.802278, LR 0.001000
Epoch 7, VEER 8.7200, MinDCF 0.45530
Epoch 8, TEER/TAcc 83.58, TLOSS 0.760561, LR 0.001000
Epoch 8, VEER 8.9500, MinDCF 0.48210
Epoch 9, TEER/TAcc 84.57, TLOSS 0.731898, LR 0.001000
Epoch 9, VEER 9.0400, MinDCF 0.44220
Epoch 10, TEER/TAcc 85.46, TLOSS 0.686976, LR 0.001000
Epoch 10, VEER 8.3700, MinDCF 0.44310
Epoch 11, TEER/TAcc 86.09, TLOSS 0.666740, LR 0.001000
Epoch 11, VEER 7.9400, MinDCF 0.43420
Epoch 12, TEER/TAcc 86.44, TLOSS 0.647690, LR 0.001000
Epoch 12, VEER 8.4600, MinDCF 0.42190
Epoch 13, TEER/TAcc 86.98, TLOSS 0.623019, LR 0.001000
Epoch 13, VEER 8.7700, MinDCF 0.43680
Epoch 14, TEER/TAcc 87.45, TLOSS 0.609619, LR 0.001000
Epoch 14, VEER 7.8400, MinDCF 0.39720
Epoch 15, TEER/TAcc 87.60, TLOSS 0.599498, LR 0.001000
Epoch 15, VEER 7.9200, MinDCF 0.43190
Epoch 16, TEER/TAcc 87.92, TLOSS 0.587507, LR 0.001000
Epoch 16, VEER 8.0000, MinDCF 0.42160
Epoch 17, TEER/TAcc 88.03, TLOSS 0.594827, LR 0.001000
Epoch 17, VEER 7.7900, MinDCF 0.39920
Epoch 18, TEER/TAcc 88.41, TLOSS 0.569369, LR 0.001000
Epoch 18, VEER 7.6600, MinDCF 0.39790
Epoch 19, TEER/TAcc 88.59, TLOSS 0.564199, LR 0.001000
Epoch 19, VEER 7.4000, MinDCF 0.41010
Epoch 20, TEER/TAcc 88.51, TLOSS 0.562075, LR 0.001000
Epoch 20, VEER 8.1200, MinDCF 0.39610
Epoch 21, TEER/TAcc 88.83, TLOSS 0.550830, LR 0.001000
Epoch 21, VEER 8.1400, MinDCF 0.38570
Epoch 22, TEER/TAcc 88.83, TLOSS 0.550863, LR 0.001000
Epoch 22, VEER 7.2800, MinDCF 0.37390
Epoch 23, TEER/TAcc 89.26, TLOSS 0.532949, LR 0.001000
Epoch 23, VEER 7.7800, MinDCF 0.39980
Epoch 24, TEER/TAcc 89.27, TLOSS 0.531968, LR 0.001000
Epoch 24, VEER 7.5600, MinDCF 0.38370
Epoch 25, TEER/TAcc 89.15, TLOSS 0.536894, LR 0.001000
Epoch 25, VEER 7.4600, MinDCF 0.39730

"""

loss_array = []
veer_array = []

lines = dataset.split('\n')
for line in lines:
    if line.startswith('Epoch'):
        match_loss = re.search(r'TLOSS (\d+\.\d+)', line)
        match_veer = re.search(r'VEER (\d+\.\d+)', line)
        if match_loss:
            loss = float(match_loss.group(1))
            loss_array.append(loss)
        if match_veer:
            veer = float(match_veer.group(1))
            veer_array.append(veer)

print("LOSS Array:", loss_array)
print("VEER Array:", veer_array)
# Out:
# LOSS Array: [4.932107, 1.791377, 1.317087, 1.090966, 0.954119, 0.865763, 0.802278, 0.760561, 0.731898, 0.686976, 0.66674, 0.64769, 0.623019, 0.609619, 0.599498, 0.587507, 0.594827, 0.569369, 0.564199, 0.562075, 0.55083, 0.550863, 0.532949, 0.531968, 0.536894]
# VEER Array: [14.25, 11.4, 10.22, 10.3, 9.52, 9.01, 8.72, 8.95, 9.04, 8.37, 7.94, 8.46, 8.77, 7.84, 7.92, 8.0, 7.79, 7.66, 7.4, 8.12, 8.14, 7.28, 7.78, 7.56, 7.46]

# %%
min(veer_array)
# Out:
# 7.84

# %%
# wavlm
loss_array = []
eer_array = []

dataset = """
1 epoch, LR 0.001000, LOSS 14.180816, ACC 0.07%, EER 39.67%, bestEER 39.67%
2 epoch, LR 0.000990, LOSS 10.555452, ACC 0.80%, EER 38.16%, bestEER 38.16%
3 epoch, LR 0.000980, LOSS 8.921599, ACC 2.74%, EER 37.99%, bestEER 37.99%
4 epoch, LR 0.000970, LOSS 7.636973, ACC 5.61%, EER 37.06%, bestEER 37.06%
5 epoch, LR 0.000961, LOSS 6.566503, ACC 8.92%, EER 35.32%, bestEER 35.32%
6 epoch, LR 0.000951, LOSS 5.658661, ACC 12.63%, EER 33.44%, bestEER 33.44%
7 epoch, LR 0.000941, LOSS 4.902534, ACC 16.54%, EER 30.76%, bestEER 30.76%
8 epoch, LR 0.000932, LOSS 4.264701, ACC 20.39%, EER 28.85%, bestEER 28.85%
9 epoch, LR 0.000923, LOSS 3.731886, ACC 24.16%, EER 26.78%, bestEER 26.78%
10 epoch, LR 0.000914, LOSS 3.300761, ACC 27.47%, EER 24.56%, bestEER 24.56%
11 epoch, LR 0.000904, LOSS 2.924095, ACC 30.67%, EER 22.82%, bestEER 22.82%
12 epoch, LR 0.000895, LOSS 2.605240, ACC 33.62%, EER 21.36%, bestEER 21.36%
13 epoch, LR 0.000886, LOSS 2.341053, ACC 36.25%, EER 19.98%, bestEER 19.98%
14 epoch, LR 0.000878, LOSS 2.117279, ACC 38.68%, EER 18.91%, bestEER 18.91%
15 epoch, LR 0.000869, LOSS 1.915365, ACC 40.86%, EER 17.81%, bestEER 17.81%
16 epoch, LR 0.000860, LOSS 1.749057, ACC 42.72%, EER 17.20%, bestEER 17.20%
17 epoch, LR 0.000851, LOSS 1.599167, ACC 44.59%, EER 16.23%, bestEER 16.23%
18 epoch, LR 0.000843, LOSS 1.477198, ACC 46.09%, EER 15.48%, bestEER 15.48%
19 epoch, LR 0.000835, LOSS 1.357320, ACC 47.72%, EER 15.21%, bestEER 15.21%
20 epoch, LR 0.000826, LOSS 1.259476, ACC 49.02%, EER 14.52%, bestEER 14.52%
21 epoch, LR 0.000818, LOSS 1.170731, ACC 50.29%, EER 14.09%, bestEER 14.09%
22 epoch, LR 0.000810, LOSS 1.089098, ACC 51.49%, EER 13.63%, bestEER 13.63%
23 epoch, LR 0.000802, LOSS 1.021965, ACC 52.48%, EER 13.27%, bestEER 13.27%
24 epoch, LR 0.000794, LOSS 0.961586, ACC 53.41%, EER 13.20%, bestEER 13.20%
25 epoch, LR 0.000786, LOSS 0.904902, ACC 54.28%, EER 12.70%, bestEER 12.70%
26 epoch, LR 0.000778, LOSS 0.851743, ACC 55.13%, EER 12.51%, bestEER 12.51%
27 epoch, LR 0.000770, LOSS 0.807552, ACC 55.81%, EER 12.51%, bestEER 12.51%
28 epoch, LR 0.000762, LOSS 0.764935, ACC 56.56%, EER 12.29%, bestEER 12.29%
29 epoch, LR 0.000755, LOSS 0.726817, ACC 57.19%, EER 11.87%, bestEER 11.87%
30 epoch, LR 0.000747, LOSS 0.693767, ACC 57.69%, EER 12.03%, bestEER 11.87%
31 epoch, LR 0.000740, LOSS 0.662371, ACC 58.23%, EER 11.94%, bestEER 11.87%
32 epoch, LR 0.000732, LOSS 0.632720, ACC 58.68%, EER 11.71%, bestEER 11.71%
33 epoch, LR 0.000725, LOSS 0.605744, ACC 59.07%, EER 11.62%, bestEER 11.62%
34 epoch, LR 0.000718, LOSS 0.584659, ACC 59.46%, EER 11.49%, bestEER 11.49%
35 epoch, LR 0.000711, LOSS 0.560828, ACC 59.79%, EER 11.36%, bestEER 11.36%
36 epoch, LR 0.000703, LOSS 0.537683, ACC 60.21%, EER 11.39%, bestEER 11.36%
"""

lines = dataset.strip().split('\n')

for line in lines:
    parts = line.split(',')
    loss = float(parts[2].split()[1])
    eer = float(parts[4].split()[1].replace('%', ''))
    loss_array.append(loss)
    eer_array.append(eer)

print("Loss array:", loss_array)
print("EER array:", eer_array)
# Out:
# Loss array: [14.180816, 10.555452, 8.921599, 7.636973, 6.566503, 5.658661, 4.902534, 4.264701, 3.731886, 3.300761, 2.924095, 2.60524, 2.341053, 2.117279, 1.915365, 1.749057, 1.599167, 1.477198, 1.35732, 1.259476, 1.170731, 1.089098, 1.021965, 0.961586, 0.904902, 0.851743, 0.807552, 0.764935, 0.726817, 0.693767, 0.662371, 0.63272, 0.605744, 0.584659, 0.560828, 0.537683]
# EER array: [39.67, 38.16, 37.99, 37.06, 35.32, 33.44, 30.76, 28.85, 26.78, 24.56, 22.82, 21.36, 19.98, 18.91, 17.81, 17.2, 16.23, 15.48, 15.21, 14.52, 14.09, 13.63, 13.27, 13.2, 12.7, 12.51, 12.51, 12.29, 11.87, 12.03, 11.94, 11.71, 11.62, 11.49, 11.36, 11.39]

# %% [markdown]
# # Zalo Scratch

# %% [markdown]
# ## RawNet3

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 40))
tloss = [7.865118, 3.624339, 1.866736, 1.210032, 0.875022, 0.691935, 0.616601, 0.547168, 0.505286, 0.476165, 0.384119, 0.338197, 0.345566, 0.338721, 0.338584, 0.351314, 0.332994, 0.318123, 0.321353, 0.308775, 0.250906, 0.238032, 0.220841, 0.222348, 0.218809, 0.213964, 0.233217, 0.221101, 0.213598, 0.205821, 0.181853, 0.167977, 0.152936, 0.163057, 0.158863, 0.168377, 0.172058, 0.164198, 0.16474]

# Plotting TLOSS
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, tloss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('LOSS')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('r3_zalo_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 40))
veer = [18.87, 12.41, 11.06, 10.8, 9.5, 8.97, 9.64, 9.01, 9.92, 9.22, 8.47, 8.98, 8.81, 8.5, 9.02, 8.0, 8.81, 8.22, 8.63, 9.09, 8.68, 8.11, 9.35, 8.4, 9.13, 8.74, 8.87, 9.36, 8.97, 9.36, 7.96, 8.46, 8.42, 8.91, 9.39, 8.77, 8.36, 8.39, 9.16]

# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('r3_zalo_eer_plot.png', dpi=300)

plt.show()

# %% [markdown]
# ## WavLM

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 56))
loss = [16.563379, 14.163586, 12.25551, 10.610897, 9.135329, 7.831573, 6.661052, 5.636991, 4.747552, 4.037534, 3.427942, 2.946433, 2.583688, 2.275546, 2.03528, 1.875361, 1.717637, 1.601139, 1.504857, 1.409197, 1.318598, 1.255968, 1.208169, 1.150966, 1.105551, 1.045232, 1.016452, 0.983005, 0.939479, 0.913507, 0.880341, 0.88752, 0.838579, 0.825736, 0.801299, 0.789559, 0.769254, 0.75276, 0.741793, 0.735955, 0.714856, 0.710335, 0.687454, 0.675577, 0.66302, 0.654747, 0.650359, 0.654959, 0.625975, 0.616197, 0.612768, 0.618905, 0.617734, 0.593214, 0.599023]

# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_zalo_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 56))
veer = [41.15, 38.8, 35.35, 32.76, 30.76, 29.19, 28.09, 27.78, 27.13, 26.48, 26.07, 25.62, 25.41, 25.05, 24.95, 24.91, 24.72, 24.61, 24.33, 24.32, 24.17, 24.15, 23.93, 23.87, 23.75, 23.67, 23.62, 23.55, 23.33, 23.35, 23.32, 23.18, 23.14, 23.15, 23.33, 23.0, 23.06, 22.95, 22.81, 22.92, 22.75, 22.75, 22.7, 22.76, 22.77, 22.7, 22.54, 22.56, 22.67, 22.62, 22.5, 22.4, 22.48, 22.57, 22.41]

# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epochs')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_zalo_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# # Transfer learning

# %% [markdown]
# ## Finetuning

# %% [markdown]
# ### RawNet3

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 33))
loss = [3.616718, 0.922912, 0.648637, 0.556445, 0.509366, 0.448861, 0.472087, 0.391327, 0.396208, 0.400717, 0.320556, 0.251909, 0.250307, 0.219667, 0.219641, 0.237172, 0.244297, 0.234527, 0.27895, 0.277734, 0.208856, 0.166973, 0.147853, 0.158982, 0.16377, 0.165589, 0.159589, 0.170302, 0.152984, 0.15088, 0.140196, 0.116627]
# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Set custom x-axis tick marks
# xticks = epoch # Custom tick positions
# ax.set_xticks(xticks)
# ax.set_xticklabels(xticks)

# Display the plot
plt.tight_layout()
plt.savefig('r3_finetune_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 33))
veer = [5.3, 5.07, 5.4, 4.43, 4.69, 5.34, 4.75, 4.97, 5.98, 4.86, 4.56, 4.81, 4.13, 4.87, 4.92, 5.44, 5.15, 5.42, 6.13, 5.14, 5.24, 4.93, 5.37, 4.94, 5.43, 5.25, 5.9, 5.18, 4.93, 5.45, 5.3, 5.07]

# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epoch')
ax.grid(True)

plt.ylim(3,8)
# Set custom x-axis tick marks
# xticks = epoch # Custom tick positions
# ax.set_xticks(xticks)
# ax.set_xticklabels(xticks)

# Display the plot
plt.tight_layout()
plt.savefig('r3_finetune_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ### Wavlm

# %%
import matplotlib.pyplot as plt

# Data for stage 1
epoch_stage1 = list(range(1, 40))
loss_stage1 = [16.055253, 13.798114, 11.764548, 10.020786, 8.575108, 7.380386, 6.426663, 5.626128, 4.959698, 4.412244, 3.969249, 3.576362, 3.260691, 2.988648, 2.759876, 2.562661, 2.396009, 2.244679, 2.124065, 2.016799, 1.92181, 1.837645, 1.755286, 1.694133, 1.631454, 1.575931, 1.526148, 1.485093, 1.442212, 1.404559, 1.337313, 1.308061, 1.284408, 1.25554, 1.23232, 1.213205, 1.197987, 1.170303, 1.159327]

# Data for stage 2
epoch_stage2 = list(range(1, 11))
loss_stage2 = [1.346844, 1.087593, 0.937732, 0.825173, 0.747318,
               0.697405, 0.643487, 0.611229, 0.565045, 0.527723]

# Plotting Loss for both stages
fig, ax = plt.subplots(1, 1, figsize=(15, 8))

# Stage 1
ax.plot(epoch_stage1, loss_stage1, marker='o', color='red', label='Giai đoạn 1')

# Stage 2
ax.plot(epoch_stage2, loss_stage2, marker='o', color='purple', label='Giai đoạn 2')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
legend = ax.legend( fontsize='x-large')
legend.get_frame()
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_finetune_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for stage 1
epoch_stage1 = list(range(1, 40))
eer_stage1 = [6.53, 7.28, 7.76, 7.83, 7.2, 6.66, 6.05, 5.73, 5.57, 5.1, 4.91, 4.58,
              4.34, 4.14, 4.12, 4.01, 3.96, 3.95, 3.89, 3.81, 3.77, 3.81, 3.72,
              3.68, 3.66, 3.6, 3.63, 3.67, 3.66, 3.58, 3.56, 3.59, 3.58, 3.56,
              3.54, 3.54, 3.52, 3.53, 3.56]

# Data for stage 2
epoch_stage2 = list(range(1, 11))
eer_stage2 = [3.22, 3.25, 3.2, 3.03, 3.06, 3.07, 2.96, 3.11, 3.19, 3.09]

# Plotting EER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch_stage1, eer_stage1, marker='o',  label='Giai đoạn 1')
ax.plot(epoch_stage2, eer_stage2, marker='o', color='purple', label='Giai đoạn 2')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epoch')
ax.grid(True)
legend = ax.legend( fontsize='x-large')
legend.get_frame()

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_finetune_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ## Component

# %% [markdown]
# ### 1 dense

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 61))
loss = [3.304165, 1.016612, 0.751447, 0.698193, 0.642833, 0.607465, 0.578897, 0.556111, 0.528754, 0.528097, 0.484043, 0.432076, 0.452913, 0.43653, 0.429241, 0.458688, 0.44044, 0.424028, 0.428698, 0.432476, 0.396064, 0.395196, 0.380076, 0.390081, 0.383438, 0.392558, 0.389986, 0.376297, 0.374515, 0.371753, 0.354323, 0.343144, 0.345047, 0.355416, 0.345713, 0.34678, 0.348782, 0.346816, 0.342481, 0.340172, 0.330972, 0.32522, 0.322182, 0.318558, 0.330533, 0.319202, 0.313083, 0.324839, 0.320224, 0.32653, 0.314647, 0.304231, 0.304023, 0.303902, 0.312333, 0.31346, 0.296086, 0.300246, 0.305021, 0.298007]

# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('r3_1dense_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 61))
veer = [6.38, 6.25, 6.19, 5.92, 5.86, 5.9, 5.83, 6.07, 6.07, 5.94, 5.95, 6.04, 5.93, 5.84, 6.13, 6.06, 5.68, 6.0, 5.83, 6.01, 6.1, 5.91, 6.06, 6.19, 6.13, 5.83, 5.75, 6.0, 6.02, 5.89, 5.65, 6.03, 5.85, 5.97, 5.93, 5.68, 5.8, 5.85, 5.96, 5.85, 5.77, 6.09, 6.06, 5.9, 6.01, 5.87, 5.72, 6.03, 5.83, 6.06, 5.96, 6.16, 6.01, 5.88, 5.96, 5.97, 5.99, 5.95, 5.79, 5.86]
# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epochs')
ax.grid(True)

# Display the plot
plt.ylim(5,7)
plt.tight_layout()
plt.savefig('r3_1dense_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 57))
loss = [16.314806, 14.752918, 13.284463, 11.957432, 10.841856, 9.89356, 9.110784, 8.426479, 7.850114, 7.351727, 6.909206, 6.515461, 6.159258, 5.842967, 5.553774, 5.296895, 5.083009, 4.850448, 4.656077, 4.501122, 4.328426, 4.179879, 4.054597, 3.926225, 3.813624, 3.723706, 3.630157, 3.546757, 3.462046, 3.39135, 3.31418, 3.254982, 3.192982, 3.135958, 3.089387, 3.033938, 2.984776, 2.951743, 2.905133, 2.873195, 2.832906, 2.806311, 2.770074, 2.738469, 2.704784, 2.690378, 2.659071, 2.636965, 2.61774, 2.594056, 2.580692, 2.559544, 2.538955, 2.519719, 2.504576, 2.478307]

# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_1dense_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 57))
veer = [7.37, 7.48, 7.55, 7.7, 7.66, 7.67, 7.7, 7.61, 7.65, 7.62, 7.47, 7.42, 7.34, 7.24, 7.12, 7.14, 7.08, 6.94, 6.98, 6.88, 6.83, 6.77, 6.72, 6.65, 6.54, 6.55, 6.54, 6.48, 6.48, 6.47, 6.43, 6.38, 6.37, 6.35, 6.33, 6.32, 6.28, 6.31, 6.26, 6.31, 6.28, 6.27, 6.24, 6.28, 6.2, 6.18, 6.2, 6.19, 6.22, 6.17, 6.23, 6.22, 6.22, 6.22, 6.22, 6.18]

# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epochs')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_1dense_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ### 3 dense

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 49))
loss = [3.409056, 1.3001, 1.026781, 0.917998, 0.847696, 0.785276, 0.758669, 0.729359, 0.6863, 0.676586, 0.593792, 0.528144, 0.539302, 0.540257, 0.529154, 0.547251, 0.548576, 0.523226, 0.538527, 0.528782, 0.472586, 0.467773, 0.445598, 0.459569, 0.46017, 0.464724, 0.461493, 0.451515, 0.454221, 0.447751, 0.413454, 0.399855, 0.399001, 0.401925, 0.392621, 0.401491, 0.395853, 0.398959, 0.399095, 0.389796, 0.380372, 0.357269, 0.360577, 0.361479, 0.365971, 0.371451, 0.353451, 0.364626]

# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('r3_3dense_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 49))
veer = [6.6, 6.59, 6.76, 6.44, 6.76, 6.86, 6.82, 6.45, 6.84, 6.26, 6.33, 6.35, 6.31, 6.25, 6.78, 6.4, 6.27, 6.8, 6.39, 6.23, 6.72, 6.32, 6.45, 6.69, 6.39, 6.14, 6.06, 6.31, 6.49, 6.18, 5.71, 5.97, 6.06, 6.21, 6.31, 6.1, 6.05, 6.23, 6.12, 6.13, 6.07, 6.38, 6.35, 6.22, 6.3, 6.16, 5.93, 6.4]

# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epochs')
ax.grid(True)

# Display the plot
plt.ylim(5,8)
plt.tight_layout()
plt.savefig('r3_3dense_eer_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 51))
loss = [15.742331, 13.660318, 12.478171, 11.768756, 11.242881, 10.746526, 10.212717, 9.601232, 8.952279, 8.337258, 7.776974, 7.278582, 6.803566, 6.398563, 6.045645, 5.70303, 5.416059, 5.135755, 4.907371, 4.686992, 4.491628, 4.316316, 4.158079, 4.012563, 3.881457, 3.765225, 3.640428, 3.548425, 3.456177, 3.365507, 3.289906, 3.205843, 3.152828, 3.090633, 3.027716, 2.975101, 2.922786, 2.875357, 2.833131, 2.791307, 2.751091, 2.706272, 2.681314, 2.64134, 2.614928, 2.587288, 2.558007, 2.537568, 2.510727, 2.485704]
# Plotting Loss
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, loss, marker='o', color='red')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss theo Epoch')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_3dense_loss_plot.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epoch = list(range(1, 51))
veer =[14.18, 14.51, 14.42, 14.07, 13.48, 12.81, 11.86, 10.96, 10.1, 9.37, 9.09, 8.66, 8.4, 8.09, 7.85, 7.61, 7.48, 7.26, 7.19, 7.08, 7.01, 6.88, 6.75, 6.65, 6.61, 6.53, 6.49, 6.36, 6.36, 6.26, 6.18, 6.18, 6.16, 6.13, 6.14, 6.09, 6.17, 6.11, 6.08, 6.05, 6.03, 6.03, 5.94, 6.0, 5.94, 5.9, 5.94, 5.93, 5.85, 5.87]
# Plotting VEER
fig, ax = plt.subplots(1, 1, figsize=(15, 8))
ax.plot(epoch, veer, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('EER%')
ax.set_title('EER theo Epochs')
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.savefig('wavlm_3dense_eer_plot.png', dpi=300)
plt.show()
