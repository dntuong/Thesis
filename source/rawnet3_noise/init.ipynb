# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/KLTN/source/rawnet3_noise/
# Out:
# /content/gdrive/MyDrive/KLTN/source/rawnet3_noise

# %%
# !pip install asteroid_filterbanks -q
# !pip install soundfile==0.10.3.post1 -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# librosa 0.10.0.post2 requires soundfile>=0.12.1, but you have soundfile 0.10.3.post1 which is incompatible.

# %% [markdown]
# # finetuned

# %%
# Signal to noise: 0 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 5.97 Hz, embedding size 256
# Computing 19900 of 20000: 3178.17 Hz
#  2023-06-22 08:35:14 VEER 18.0900 MinDCF 0.81930

# %%
# Signal to noise: 2 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.22 Hz, embedding size 256
# Computing 19900 of 20000: 3614.84 Hz
#  2023-06-22 08:43:54 VEER 16.5100 MinDCF 0.79150

# %%
# Signal to noise: 4 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.03 Hz, embedding size 256
# Computing 19900 of 20000: 3632.06 Hz
#  2023-06-22 08:47:30 VEER 15.8800 MinDCF 0.76800

# %%
# Signal to noise: 6 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.01 Hz, embedding size 256
# Computing 19900 of 20000: 3271.67 Hz
#  2023-06-22 08:50:38 VEER 14.7800 MinDCF 0.73060

# %%
# Signal to noise: 8 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.06 Hz, embedding size 256
# Computing 19900 of 20000: 3518.47 Hz
#  2023-06-22 08:55:06 VEER 13.9900 MinDCF 0.69650

# %%
# Signal to noise: 10 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.02 Hz, embedding size 256
# Computing 19900 of 20000: 2976.20 Hz
#  2023-06-22 08:58:03 VEER 13.4100 MinDCF 0.68320

# %%
# Signal to noise: 12 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.71 Hz, embedding size 256
# Computing 19900 of 20000: 3616.85 Hz
#  2023-06-22 10:22:41 VEER 12.4400 MinDCF 0.63690

# %%
# Signal to noise: 14 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.64 Hz, embedding size 256
# Computing 19900 of 20000: 3418.33 Hz
#  2023-06-22 10:25:22 VEER 11.9000 MinDCF 0.62410

# %%
# Signal to noise: 16 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.68 Hz, embedding size 256
# Computing 19900 of 20000: 3480.52 Hz
#  2023-06-22 10:28:57 VEER 11.4500 MinDCF 0.58570

# %%
# Signal to noise: 18 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.64 Hz, embedding size 256
# Computing 19900 of 20000: 3396.83 Hz
#  2023-06-22 10:31:42 VEER 10.4300 MinDCF 0.57170

# %%
# Signal to noise: 20 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.67 Hz, embedding size 256
# Computing 19900 of 20000: 3560.41 Hz
#  2023-06-22 10:34:59 VEER 9.7400 MinDCF 0.54650

# %%
# Signal to noise: 22 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.68 Hz, embedding size 256
# Computing 19900 of 20000: 3492.43 Hz
#  2023-06-22 10:38:35 VEER 9.2300 MinDCF 0.53960

# %%
# Signal to noise: 24 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.68 Hz, embedding size 256
# Computing 19900 of 20000: 3320.93 Hz
#  2023-06-22 10:42:15 VEER 8.8400 MinDCF 0.49430

# %%
# Signal to noise: 26 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.65 Hz, embedding size 256
# Computing 19900 of 20000: 3647.59 Hz
#  2023-06-22 10:45:17 VEER 7.9400 MinDCF 0.47820

# %%
# Signal to noise: 28 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.64 Hz, embedding size 256
# Computing 19900 of 20000: 2888.19 Hz
#  2023-06-22 10:48:37 VEER 7.4900 MinDCF 0.46340

# %%
# Signal to noise: 30 db
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer/exps/RawNet3_AAM/model/model000000013.model loaded!
# Total parameters:  16280322
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.60 Hz, embedding size 256
# Computing 19900 of 20000: 2881.92 Hz
#  2023-06-22 10:51:25 VEER 7.0200 MinDCF 0.43860
