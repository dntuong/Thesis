# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/KLTN/source/rawnet3_lowpass/
# Out:
# /content/gdrive/MyDrive/KLTN/source/rawnet3_lowpass

# %%
# !pip install asteroid_filterbanks -q
# !pip install soundfile==0.10.3.post1 -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# librosa 0.10.0.post2 requires soundfile>=0.12.1, but you have soundfile 0.10.3.post1 which is incompatible.

# %% [markdown]
# # low pass filter

# %%
# 500 -> chinh file datasetloader.py
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.20 Hz, embedding size 256
# Computing 19900 of 20000: 3556.61 Hz
#  2023-06-21 19:24:48 VEER 36.1400 MinDCF 0.99940

# %%
# 1000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.23 Hz, embedding size 256
# Computing 19900 of 20000: 3438.45 Hz
#  2023-06-21 19:27:46 VEER 32.6300 MinDCF 0.98840

# %%
# 1500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.28 Hz, embedding size 256
# Computing 19900 of 20000: 3082.46 Hz
#  2023-06-21 19:31:42 VEER 27.0800 MinDCF 0.94800

# %%
# 2000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.22 Hz, embedding size 256
# Computing 19900 of 20000: 3255.89 Hz
#  2023-06-21 19:34:38 VEER 19.6400 MinDCF 0.83630

# %%
# 2500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.23 Hz, embedding size 256
# Computing 19900 of 20000: 3542.55 Hz
#  2023-06-21 19:37:34 VEER 17.9900 MinDCF 0.76420

# %%
# 3000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.25 Hz, embedding size 256
# Computing 19900 of 20000: 3366.89 Hz
#  2023-06-21 19:40:36 VEER 14.5300 MinDCF 0.60410

# %%
# 3500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.26 Hz, embedding size 256
# Computing 19900 of 20000: 3084.11 Hz
#  2023-06-21 19:43:52 VEER 11.5400 MinDCF 0.50620

# %%
# 4000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.23 Hz, embedding size 256
# Computing 19900 of 20000: 3069.26 Hz
#  2023-06-21 19:46:48 VEER 12.1000 MinDCF 0.56380

# %%
# 4500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.25 Hz, embedding size 256
# Computing 19900 of 20000: 2763.85 Hz
#  2023-06-21 19:49:54 VEER 14.5000 MinDCF 0.68820

# %%
# 5000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.23 Hz, embedding size 256
# Computing 19900 of 20000: 3468.99 Hz
#  2023-06-21 19:52:51 VEER 19.7500 MinDCF 0.86530

# %%
# 5500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.23 Hz, embedding size 256
# Computing 19900 of 20000: 3355.01 Hz
#  2023-06-21 19:55:42 VEER 24.5900 MinDCF 0.95090

# %%
# 6000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.26 Hz, embedding size 256
# Computing 19900 of 20000: 3537.50 Hz
#  2023-06-21 19:59:02 VEER 25.0800 MinDCF 0.98310

# %%
# 6500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.24 Hz, embedding size 256
# Computing 19900 of 20000: 3513.07 Hz
#  2023-06-21 20:01:54 VEER 30.6500 MinDCF 0.99950

# %%
# 7000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.27 Hz, embedding size 256
# Computing 19900 of 20000: 3411.25 Hz
#  2023-06-21 20:05:10 VEER 9.6300 MinDCF 0.43550

# %%
# 7500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.26 Hz, embedding size 256
# Computing 19900 of 20000: 3141.81 Hz
#  2023-06-21 20:08:14 VEER 6.2900 MinDCF 0.30970

# %% [markdown]
# # bandstop filter

# %%
# bandstop 4000 - 6500
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.15 Hz, embedding size 256
# Computing 19900 of 20000: 3312.60 Hz
#  2023-06-22 08:57:11 VEER 9.0600 MinDCF 0.43770

# %%
# bandstop 4500 - 7000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.26 Hz, embedding size 256
# Computing 19900 of 20000: 3126.11 Hz
#  2023-06-22 06:58:27 VEER 9.4700 MinDCF 0.46780

# %%
# bandstop 4000 - 7000
# !python ./trainSpeakerNet.py --eval --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model --max_epoch 20
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model /content/gdrive/MyDrive/KLTN/source/voxceleb_trainer_1dense/exps/RawNet3_AAM/model/model000000031.model loaded!
# Total parameters:  16346114
# Test list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt
# Reading 900 of 973: 6.50 Hz, embedding size 256
# Computing 19900 of 20000: 3285.91 Hz
#  2023-06-22 07:03:33 VEER 10.1700 MinDCF 0.46990
