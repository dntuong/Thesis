# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/KLTN/source/rawnet3_finetune/
# Out:
# /content/gdrive/MyDrive/KLTN/source/rawnet3_finetune

# %%
# !pip install asteroid_filterbanks -q
# !pip install soundfile==0.10.3.post1 -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# librosa 0.10.0.post2 requires soundfile>=0.12.1, but you have soundfile 0.10.3.post1 which is incompatible.

# %%
# !python ./trainSpeakerNet.py --config ./configs/RawNet3_AAM.yaml --train_list ../../dataset/zalo_dataset/dataset_fix/train_list.txt --train_path ../../dataset/zalo_dataset/dataset_fix/train --test_list ../../dataset/zalo_dataset/dataset_fix/veri_val.txt --test_path ../../dataset/zalo_dataset/dataset_fix/val --initial_model ../rawnet3/model.pt --max_epoch 60
# Out:
# Python Version: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# PyTorch Version: 2.0.1+cu118
# Number of GPUs: 1
# Save path: exps/RawNet3_AAM
# self.encoder_type ECA
# Initialised AAMSoftmax margin 0.100 scale 30.000
# Initialised Adam optimizer
# Initialised step LR scheduler
# Model ../rawnet3/model.pt loaded!
# Processing 8000 of 8000:Loss 3.616718 TEER/TAcc 43.275% - 1.96 Hz
#  2023-06-21 08:11:34 Epoch 1, TEER/TAcc 43.27, TLOSS 3.616718, LR 0.001000
# Reading 900 of 973: 6.38 Hz, embedding size 256
# Computing 19900 of 20000: 2989.03 Hz
#  2023-06-21 08:14:13 Epoch 1, VEER 5.3000, MinDCF 0.34690
# Processing 8064 of 8064:Loss 0.922912 TEER/TAcc 80.717% - 27.34 Hz
#  2023-06-21 08:23:13 Epoch 2, TEER/TAcc 80.72, TLOSS 0.922912, LR 0.001000
# Reading 900 of 973: 6.40 Hz, embedding size 256
# Computing 19900 of 20000: 3240.62 Hz
#  2023-06-21 08:25:51 Epoch 2, VEER 5.0700, MinDCF 0.34900
# Processing 8032 of 8032:Loss 0.648637 TEER/TAcc 86.118% - 27.58 Hz
# ...
